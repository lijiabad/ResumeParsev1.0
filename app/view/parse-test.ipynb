# %%
import requests

API_KEY = "N8pHqNH39aBMON4S2i7WwbFw"
SECRET_KEY = "tkbAqcTz8oRWfj3YHxGQqc3ALYUA7rtV"

def main():
        
    url = "https://aip.baidubce.com/rpc/2.0/nlp/v1/txt_keywords_extraction?access_token=24.12de01f22dfa110564b9a9f8125e4b0b.2592000.1688567216.282335-34434607"
    
    print(url)
    # payload = ""
    # payload = { 
    #     "text":[  
    #         "学习书法，就选唐颜真卿《颜勤礼碑》原碑与对临「第1节」" 
    #         ], 
    #     "num":4
    # }
    payload = "{\"text\":[\"{     \\\"text\\\":[         \\\"学习书法，就选唐颜真卿《颜勤礼碑》原碑与对临「第1节」\\\"     ],     \\\"num\\\":4 }\"],\"num\":3}"
    payload.encode('utf-8')
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    
    response = requests.request("POST", url, headers=headers, data=payload)
    
    print(response.text)
    

if __name__ == '__main__':
    main()
# Out:
# https://aip.baidubce.com/rpc/2.0/nlp/v1/txt_keywords_extraction?access_token=24.12de01f22dfa110564b9a9f8125e4b0b.2592000.1688567216.282335-34434607
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-11-0e22e8698d99> in <module>
#      28
#      29 if __name__ == '__main__':
# ---> 30     main()
#
# <ipython-input-11-0e22e8698d99> in main()
#      22     }
#      23
# ---> 24     response = requests.request("POST", url, headers=headers, data=payload)
#      25
#      26     print(response.text)
#
# d:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
import requests


def main():
        
    url = "https://aip.baidubce.com/rpc/2.0/nlp/v1/txt_keywords_extraction?access_token=24.12de01f22dfa110564b9a9f8125e4b0b.2592000.1688567216.282335-34434607"
    
    payload = "{\"text\":[\"{     \\\"text\\\":[         \\\"学习书法，就选唐颜真卿《颜勤礼碑》原碑与对临「第1节」\\\"     ],     \\\"num\\\":4 }\"],\"num\":3}"
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    payload.encode('utf-8')
    response = requests.request("POST", url, headers=headers, data=payload)
    
    print(response.text)
    

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-16-c0c57a7e29df> in <module>
#      17
#      18 if __name__ == '__main__':
# ---> 19     main()
#
# <ipython-input-16-c0c57a7e29df> in main()
#      11     }
#      12     payload.encode('utf-8')
# ---> 13     response = requests.request("POST", url, headers=headers, data=payload)
#      14
#      15     print(response.text)
#
# d:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...
